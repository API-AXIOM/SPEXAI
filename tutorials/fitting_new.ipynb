# %% [markdown]
# # Tutorial on inference with SPEXAI
#
# This tutorial explains how you can use SPEXAI to fit observered spectra from a FITS file.

# %%
# %load_ext autoreload
# %autoreload 2 
# %aimport spexai.inference

# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("paper")

import numpy as np
import pickle
#from spexai.inference import SingleTemp, TwoTemp, TempDist
#from spexai.inference import CombinedModel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Fitting an One-Temperature Model
#
# Simulated data or real data can be model with a one temperuture model by  ```Fit```
#
# The paramater that are fitted are the
# - Temperature in KeV  ```temp``` (between 0.2 and 10 KeV)
# - Metalicity [solar] ```met```  (larger than 0)
# - Turbulent velocity in km/sec ```vel``` (between 0 and 600 km/sec)
# - Redshift in log10(z) ```logz``` (between -10 and 1)
# - Normalisation ```norm``` (between 1e5 and 1e15)
#
# Additional parameter(s)
# - Single element ```X``` abundace ratio with respect to Iron ```ZX```, where ```X``` is tha atom number (larger then 0)
#
# The intial guess with there standard diviation of all the parameters that are fitted can be put into the dictiornary of the ```prior```.

# %%
#intial guess and prior for fit
prior = {
        'temp': {'mu': 5,    'sigma': 2},
        'met' : {'mu': 1,    'sigma': .3},
        'vel' : {'mu': 100,  'sigma': 50},
        'logz': {'mu': -3,   'sigma': 1},
        'norm': {'mu': 1e4, 'sigma':1e3}
        }

# %% [markdown]
# The ensemble samper can be intialized with ```nwalkers``` and ```nsteps``` for the walker to go through, ```prior``` indicates the intial values for the parameters and there Gaussion prior in the likelihood, other parameter that can be initialized are the Luminosity Distance in m and the energy interval of the spectrum in KeV (```e_min``` > 0.1; ```e_max``` < 25).
#
# ```fdir_nn``` is the file directory to the trained neural networks and should match the path on your device.

# %%
#initialize thes
fit = Fit(50, 800, prior, Luminosity_Distance=1e25, 
          fdir_nn='/Users/daniela/work/repositories/spexai/neuralnetworks/', 
          e_max=15)
# Out:
# Using cpu

# %% [markdown]
# ### Reading in the FITS files
#
# To be able to fit real data the response of the telescope can be read in by the FITS file, for the Response Matrix File (RMF), effective area response file (ARF).
#
# The data used for fitting can be read in from a FITS file of the observed data ```Fit.load_data```, or can be simulated by the model with ```Fit.sim_data(params)``` here ```params``` is a dictornary with the parameter names and there values.
#
# In addition the response files there is a sparse matrix (```make_sparsex```) used for convulation that implements line broadening to the spectra. The speed an accuracy of the line broadening is strongly dependent on the kernel size of the convulolution ```n``` and the default ```n=300```, increasing ```n``` will make the line-broading more accurete but will also segnifcanly impact the speed.

# %%
datadir = "/Users/daniela/work/data/xrism/"
nn_dir = "/Users/daniela/work/repositories/spexai/neuralnetworks/"

# %%
combined_model = spexai.inference.model.CombinedModel(lumdist=1e25, 
                                                      fdir_nn=nn_dir)

# %%
combined_model.load_matrices(datadir)
combined_model.sm_x_csr = combined_model.sm_x.to_sparse_csr()

# %%
'''This step can take a long time to run'''
#reading in the response matrix file
#combined_model.load_rm(datadir+'resolve_h5ev_2019a.rmf')
# Out:
# 'This step can take a long time to run'

# %%
#reading in the effective area
combined_model.load_arf(datadir+'/resolve_pnt_spec_noGV_20190611.arf')

# %%
'''This step can take a long time to run'''
#initializing the sparse matrix for the convolution from line-broadening
#combined_model.load_sparsematrix_x(n=200)
# Out:
# 'This step can take a long time to run'

# %% [markdown]
# The step loading the XRISM response file and constructing the sparse matrix for line-broadening can take ~several minutes. If you anticipate having to load these often, you can temporarily store the sparse `torch` tensors constructed in the methods above to Python `pickle` files for orders of magnitude faster loading.
#
# Note that long-term storage in `pickle` files is not recommended, because loading the binary format depends on the exact versions of the Python packages installed during the pickling process (i.e. if the Python environment changes, they might no longer load).
#
# **Important**: The code only saves/loads the response matrix and the sparse matrix for line broadening from file. The ARF needs to be loaded from its original file every time, but this operation is generally fast.

# %%
"""
combined_model.rm = rm
combined_model.arf = arf

combined_model.new_e_cent = new_e_cent
combined_model.new_e_diff = new_e_diff
#energy channels
combined_model.chan_cent = chan_cent
combined_model.chan_diff = chan_diff

combined_model.diag_index = diag_index
combined_model.rebin_interp = rebin_interp

combined_model.sm_x = sm_x

"""
rm = combined_model.rm
arf = combined_model.arf

new_e_cent = combined_model.new_e_cent
new_e_diff = combined_model.new_e_diff
#energy channels
chan_cent = combined_model.chan_cent
chan_diff = combined_model.chan_diff

diag_index = combined_model.diag_index
rebin_interp = combined_model.rebin_interp

sm_x = combined_model.sm_x

# %%
with open(datadir+"xrism_rmf.pkl", "wb") as f:
    pickle.dump(rm, f)
    
with open(datadir+"new_e_cent.pkl", "wb") as f:
    pickle.dump(new_e_cent, f)

with open(datadir+"chan_cent.pkl", "wb") as f:
    pickle.dump(chan_cent, f)
    
with open(datadir+"chan_diff.pkl", "wb") as f:
    pickle.dump(chan_diff, f)

with open(datadir+"diag_index.pkl", "wb") as f:
    pickle.dump(diag_index, f)
    
with open(datadir+"rebin_interp.pkl", "wb") as f:
    pickle.dump(rebin_interp, f)

with open(datadir+"sm_x.pkl", "wb") as f:
    pickle.dump(sm_x, f)

"""

with open(datadir+"xrism_rmf.pkl", "rb") as f:
    combined_model.rm = pickle.load(f)
    
with open(datadir+"new_e_cent.pkl", "rb") as f:
    combined_model.new_e_cent = pickle.load(f)

with open(datadir+"chan_cent.pkl", "rb") as f:
    combined_model.chan_cent = pickle.load(f)

with open(datadir+"chan_diff.pkl", "rb") as f:
    combined_model.chan_diff = pickle.load(f)

with open(datadir+"diag_index.pkl", "rb") as f:
    combined_model.diag_index = pickle.load(f)
    
with open(datadir+"rebin_interp.pkl", "rb") as f:
    combined_model.rebin_interp = pickle.load(f)

    
with open(datadir+"sm_x.pkl", "rb") as f:
    combined_model.sm_x = pickle.load(f)
"""
# Out:
# '\n\nwith open(datadir+"xrism_rmf.pkl", "rb") as f:\n    combined_model.rm = pickle.load(f)\n    \nwith open(datadir+"new_e_cent.pkl", "rb") as f:\n    combined_model.new_e_cent = pickle.load(f)\n\nwith open(datadir+"chan_cent.pkl", "rb") as f:\n    combined_model.chan_cent = pickle.load(f)\n\nwith open(datadir+"chan_diff.pkl", "rb") as f:\n    combined_model.chan_diff = pickle.load(f)\n\nwith open(datadir+"diag_index.pkl", "rb") as f:\n    combined_model.diag_index = pickle.load(f)\n    \nwith open(datadir+"rebin_interp.pkl", "rb") as f:\n    combined_model.rebin_interp = pickle.load(f)\n\n    \nwith open(datadir+"sm_x.pkl", "rb") as f:\n    combined_model.sm_x = pickle.load(f)\n'

# %% [markdown]
# ### Simulating Data
#
# We can simulated data from the model like so:

# %%
true_params = {'temp':5,'logz':-2, 'vel':100, 'met':1.2, 'norm':1e5, 'Z8':1.2, 'Z14':0.9}
exp_time = 50000

energy, counts, intensity = combined_model.simulate_data(true_params, ntemp=1, 
                                          dist_func=None, exp_time=exp_time, 
                                          e_min=None, e_max=None)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,4))
ax.plot(energy, counts)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# When loading data from file, the relevant data arrays (`counts` and `exp_time`) will automatically be loaded into attributes of the `CombinedModel` class. For simulated data, we'll have to do this ourselves:

# %%
import torch

# %%
combined_model.counts = torch.Tensor(counts)
combined_model.exp_time = exp_time

# %% [markdown]
# ### Building an object to do inference

# %%
prior
# Out:
# {'temp': {'mu': 5, 'sigma': 2},
#  'met': {'mu': 1, 'sigma': 0.3},
#  'vel': {'mu': 100, 'sigma': 50},
#  'logz': {'mu': -3, 'sigma': 1},
#  'norm': {'mu': 10000.0, 'sigma': 1000.0},
#  'Z8': {'mu': 1, 'sigma': 0.3},
#  'Z14': {'mu': 1, 'sigma': 0.3}}

# %%
#initialize thes
fit = spexai.inference.fit_new.SingleTemp(torch.Tensor(counts), combined_model, prior,
                 e_min=0.1, e_max=15.0, fdir_nn='neuralnetworks/')
# Out:
# Using cpu

# %%
true_params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 100000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %%
fit.log_posterior(params)
# Out:
# -90453.26326428443

# %% [markdown]
# This will break, because the dictionary defining the priors contains priors for fewer parameters than the parameters being put into the model. We'll need to either define a set of priors for the full parameters we need, but we can also add priors like so:

# %%
#names of aditional fitted parameters 
add_prior = {'Z8':{'mu':1, 'sigma':.3},'Z14':{'mu':1, 'sigma':.3}}
fit.add_prior(add_prior)

# %% [markdown]
# Let's try again:

# %%
fit.log_posterior(params)
# Out:
# -90453.26326428443

# %%
fit.log_prior(params)
# Out:
# -4065.333576784425

# %%
params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 100000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %%
fit.prior
# Out:
# {'temp': {'mu': 5, 'sigma': 2},
#  'met': {'mu': 1, 'sigma': 0.3},
#  'vel': {'mu': 100, 'sigma': 50},
#  'logz': {'mu': -3, 'sigma': 1},
#  'norm': {'mu': 10000.0, 'sigma': 1000.0},
#  'Z8': {'mu': 1, 'sigma': 0.3},
#  'Z14': {'mu': 1, 'sigma': 0.3}}

# %%
true_params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 100000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %%
#intial guess and prior for fit
prior_all = {
        'temp': {'mu': 5,    'sigma': 1},
        'met' : {'mu': 1.2,    'sigma': .1},
        'vel' : {'mu': 100,  'sigma': 50},
        'logz': {'mu': -2,   'sigma': 0.5},
        'norm': {'mu': 1e4, 'sigma':1e3},
        'Z8':{'mu':1.2, 'sigma':.1},
        'Z14':{'mu':0.9, 'sigma':.1}
        }

# %% [markdown]
# **TODO**:
# * `norm` should be `lognorm`
# * we probably don't want gaussian priors everywhere --> user should probably be able to just define a prior function that takes the parameters and returns the value for the prior
# * `log_prob` needs a docstring!
# * **IMPORTANT**: `sim_data` changes the state of a bunch of variables, which is BAD! I need to fix that! In general, there's a bunch of things that are entangled that shouldn't be!

# %%
test_params = [5.0, -2, 100, 1.2, 10000.0, 1.2, 0.9]

fit.log_prob(test_params, params.keys())
# Out:
# (-7331988.8335767845, [])

# %%
fit.log_likelihood(params)
# Out:
# array(-86387.93, dtype=float32)

# %%
fit.log_prior(params)
# Out:
# -4065.333576784425

# %% [markdown]
# ## Modelling with Emcee, by hand
#
# Something is not right with the modeling, so let's try to do this by hand:

# %%
true_params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 100000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %%
dict_abund = {}
for i in torch.arange(6,31):
    dict_abund[f'Z{i}'] = true_params['met']
    for key in true_params.keys():
        if key == f'Z{i}':
            dict_abund[f'Z{i}'] = true_params['met']*true_params[key]

# %%
temp = torch.tensor([true_params['temp']], dtype=torch.float32)

ymodel = combined_model.forward(temp, dict_abund, true_params["logz"], true_params["norm"], true_params["vel"])

# %%
yflux = ymodel * combined_model.chan_diff * combined_model.exp_time

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,4))
ax.plot(energy, counts)
ax.plot(energy, yflux.detach().numpy())
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Okay, that looks about right.
#
#
# ### Likelihood Function

# %%
true_params.keys()
# Out:
# dict_keys(['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14'])

# %%
from scipy.special import gammaln as scipy_gammaln

def calculate_ymodel(param_list, model):
    temp = param_list[0]
    logz = param_list[1]
    vel = param_list[2]
    met = param_list[3]
    norm = param_list[4]
    z = {"Z8": param_list[5],
         "Z14": param_list[6]}

    #intialize list of abunadace
    dict_abund = {}
    for i in torch.arange(6,31):
        dict_abund[f'Z{i}'] = met
        for key in z.keys():
            if key == f'Z{i}':
                dict_abund[f'Z{i}'] = met*z[f'Z{i}']

    #counts = torch.tensor(counts, dtype=torch.float32)
    temp = torch.tensor([temp], dtype=torch.float32)
    ymodel = model.forward(temp, dict_abund, logz, norm, vel) 
    yflux = ymodel * combined_model.chan_diff * combined_model.exp_time + 1e-30

    return yflux

def loglikelihood(param_list, counts, model):
    yflux = calculate_ymodel(param_list, model)

    loglike = torch.sum(-yflux + counts * torch.log(yflux) - torch.special.gammaln(counts + 1.))
    
    if not torch.isfinite(loglike):
        return torch.tensor([-100000000000], dtype=torch.float32)
    else:
        return loglike

# %%
loglikelihood(param_list, combined_model.counts, combined_model)
# Out:
# tensor(-89893.0312, grad_fn=<SumBackward0>)

# %%
# %timeit loglikelihood(param_list, combined_model.counts, combined_model)
# Out:
# 231 ms ± 12.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
param_list
# Out:
# [5, -2, 100, 1.2, 100000.0, 1.2, 0.9]

# %%
true_params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 100000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %%
def logprior(param_list):
    temp = torch.tensor([param_list[0]], dtype=torch.float32)
    logz = torch.tensor([param_list[1]], dtype=torch.float32)
    vel = torch.tensor([param_list[2]], dtype=torch.float32)
    met = torch.tensor([param_list[3]], dtype=torch.float32)
    norm = torch.tensor([param_list[4]], dtype=torch.float32)
    z = {"Z8": torch.tensor([param_list[5]], dtype=torch.float32),
         "Z14": torch.tensor([param_list[6]], dtype=torch.float32)}

    
    lp = 0
    lp += torch.distributions.Normal(5, 0.1).log_prob(temp)
    lp += torch.distributions.Normal(-2, 0.1).log_prob(logz)
    lp += torch.distributions.Normal(100, 10).log_prob(vel)
    lp += torch.distributions.Normal(1.0, 0.1).log_prob(met)
    lp += torch.distributions.Normal(1e5, 1e4).log_prob(norm)
    lp += torch.distributions.Normal(1.2, 0.1).log_prob(z["Z8"])
    lp += torch.distributions.Normal(0.9, 0.1).log_prob(z["Z14"])
    
    return lp

# %%
# %timeit logprior(param_list)
# Out:
# 699 µs ± 95.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
test_params = [5, -2, 100, 1.0, 100000.0, 1.2, 0.9]
print(f"prior: {logprior(test_params)}")
print(f"likelihood: {loglikelihood(test_params, combined_model.counts, combined_model)}")
# Out:
# prior: tensor([-6.4326])
# likelihood: -96535.3984375

# %%
param_list_wrong = [5, -2, 100, 1.2, 100000.0, -1.2, 0.9]
loglikelihood(param_list_wrong, combined_model.counts, combined_model)
# Out:
# tensor([-1.0000e+11])

# %% [markdown]
# Okay, that seems to work.

# %%
def logprob(param_list, counts, model):
    lp = logprior(param_list)
    if not np.isfinite(lp):
        return -np.inf
    
    ll = loglikelihood(param_list, counts, model)
    lpost = ll + lp
    return lpost.detach().numpy()

# %%
# %timeit logprob(test_params, combined_model.counts, combined_model)
# Out:
# 241 ms ± 41.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
logprob(test_params, combined_model.counts, combined_model)
# Out:
# array([-96541.83], dtype=float32)

# %% [markdown]
# ### Maximum A Posteriori Estimation

# %%
def nll(*args):
    print(args[0])
    ll = -loglikelihood(*args).detach().numpy()
    print(ll)
    return ll

#nll = lambda *args: -loglikelihood(*args).detach().numpy()

# %%
start_pars = test_params + np.random.normal(size=len(test_params))

# %%
from scipy.optimize import minimize
soln = minimize(nll, start_pars, args=(combined_model.counts, combined_model), method="Powell")
# Out:
# [ 5.00975939e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 318745.3
# [ 5.00975939e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 318745.3
# [ 6.00975939e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 321987.7
# [ 3.39172539e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 447229.7
# [ 4.39172542e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 337676.78
# [ 5.39172539e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316379.5
# [ 5.32746679e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316367.06
# [ 5.35478239e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316354.78
# [ 5.35133216e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316354.9
# [ 5.35823262e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316355.12
# [ 5.35478239e+00 -1.94505168e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 316354.78
# [ 5.35478239e+00 -9.45051675e-01  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 525435.5
# [ 5.35478239e+00 -3.56308568e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 456539.8
# [ 5.35478239e+00 -2.56308565e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 470549.47
# [ 5.35478239e+00 -1.56308568e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 537425.1
# [ 5.35478239e+00 -2.10345674e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
# 347008.75
# [ 5.35478239e+00 -1.79915365e+00  1.01124841e+02  3.97533837e-01
#   9.99980015e+04  1.85890686e+00  2.39289961e+00]
#
#   1.00004757e+05  1.20011224e+00  9.19409007e-01]
# 89886.32
# [ 5.00279101e+00 -2.00000678e+00  1.00142261e+02  1.20176145e+00
#   1.00005437e+05  1.20007918e+00  9.19393948e-01]
# 89886.305
# [ 5.00279440e+00 -2.00000675e+00  1.00142123e+02  1.20177078e+00
#   1.00005054e+05  1.20009783e+00  9.19402439e-01]
# 89886.305
# [ 5.00279210e+00 -2.00000677e+00  1.00142217e+02  1.20176446e+00
#   1.00005313e+05  1.20008520e+00  9.19396687e-01]
# 89886.31
# [ 5.00279340e+00 -2.00000676e+00  1.00142164e+02  1.20176803e+00
#   1.00005167e+05  1.20009232e+00  9.19399931e-01]
# 89886.28
# [ 5.00279309e+00 -2.00000677e+00  1.00142176e+02  1.20176717e+00
#   1.00005202e+05  1.20009062e+00  9.19399156e-01]
# 89886.31
# [ 5.00279378e+00 -2.00000676e+00  1.00142148e+02  1.20176908e+00
#   1.00005123e+05  1.20009442e+00  9.19400889e-01]
# 89886.35
# [ 5.00279355e+00 -2.00000676e+00  1.00142158e+02  1.20176843e+00
#   1.00005150e+05  1.20009312e+00  9.19400297e-01]
# 89886.32
# [ 5.00279328e+00 -2.00000676e+00  1.00142168e+02  1.20176770e+00
#   1.00005180e+05  1.20009167e+00  9.19399635e-01]
# 89886.28
# [ 5.00279321e+00 -2.00000676e+00  1.00142171e+02  1.20176750e+00
#   1.00005188e+05  1.20009127e+00  9.19399452e-01]
# 89886.29
# [ 5.00279333e+00 -2.00000676e+00  1.00142167e+02  1.20176782e+00
#   1.00005175e+05  1.20009192e+00  9.19399748e-01]
# 89886.26
# [ 5.00279334e+00 -2.00000676e+00  1.00142166e+02  1.20176786e+00
#   1.00005173e+05  1.20009199e+00  9.19399783e-01]
# 89886.305
# [ 5.00279332e+00 -2.00000676e+00  1.00142167e+02  1.20176781e+00
#   1.00005176e+05  1.20009189e+00  9.19399734e-01]
# 89886.266
# [ 5.00279333e+00 -2.00000676e+00  1.00142166e+02  1.20176784e+00
#   1.00005174e+05  1.20009195e+00  9.19399761e-01]
# 89886.26

# %%
test_params
# Out:
# [5, -2, 100, 1.0, 100000.0, 1.2, 0.9]

# %%
start_pars
# Out:
# array([ 5.00975939e+00, -1.94505168e+00,  1.01124841e+02,  3.97533837e-01,
#         9.99980015e+04,  1.85890686e+00,  2.39289961e+00])

# %%
soln.x
# Out:
# array([ 5.00279333e+00, -2.00000676e+00,  1.00142166e+02,  1.20176784e+00,
#         1.00005174e+05,  1.20009195e+00,  9.19399761e-01])

# %%
soln.message
# Out:
# 'Optimization terminated successfully.'

# %%
yfit = calculate_ymodel(soln.x, combined_model)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,4))
ax.plot(energy, counts)
ax.plot(energy, yflux.detach().numpy(), alpha=0.5)
ax.plot(energy, yfit.detach().numpy(), alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### MCMC
#
# Let's run MCMC. We'll do two runs. One, where we initialize the MCMC run from the prior, and a second one, where we initialize the MCMC run from the optimization result above.

# %%
ndim = len(test_params)
nwalkers = torch.tensor([20])

# %%
initial_pos = np.array([np.random.normal(5, 0.1, nwalkers),
               np.random.normal(-2, 0.1, nwalkers),
               np.random.normal(100, 10, nwalkers),
               np.random.normal(1.0, 0.1, nwalkers),
               np.random.normal(1e5, 1e4, nwalkers),
               np.random.normal(1.2, 0.1, nwalkers),
               np.random.normal(0.9, 0.1, nwalkers)
              ]).T

# %%
nwalkers, ndim = initial_pos.shape

# %%
import emcee

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, logprob, args=(combined_model.counts, combined_model))

# %%
sampler.run_mcmc(initial_pos, 1000, progress=True);
# Out:
# 100%|███████████████████████████████████████████████| 1000/1000 [1:42:59<00:00,  6.18s/it]

# %%
samples.shape
# Out:
# (100, 20, 7)

# %%
labels = list(params.keys())
print(labels)

fig, axes = plt.subplots(ndim, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");
# Out:
# ['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14']
# <img src="data:image/png;base64,..." width="1000">

# %%
import corner

# %%
flat_samples = sampler.get_chain(discard=600, thin=10, flat=True)

# %%
fig = plt.figure(figsize=(8,8))
corner.corner(flat_samples, fig=fig, labels = list(params.keys()),
              truths=list(true_params.values()))
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# #### MCMC, but from the Optimizer Solution

# %%
initial_pos = soln.x + np.random.normal(size=(nwalkers, ndim)) * 1e-3

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, logprob, args=(combined_model.counts, combined_model))

# %%
sampler.run_mcmc(initial_pos, 1000, progress=True);
# Out:
#   0%|                                                  | 2/1000 [00:14<1:57:30,  7.06s/it]Traceback (most recent call last):
#   File "/opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/var/folders/cm/2d1tk8fs125435tgbw22nb0h0000gp/T/ipykernel_84236/1989119161.py", line 6, in logprob
#     ll = loglikelihood(param_list, counts, model)
#   File "/var/folders/cm/2d1tk8fs125435tgbw22nb0h0000gp/T/ipykernel_84236/2908543453.py", line 28, in loglikelihood
#     yflux = calculate_ymodel(param_list, model)
#   File "/var/folders/cm/2d1tk8fs125435tgbw22nb0h0000gp/T/ipykernel_84236/2908543453.py", line 22, in calculate_ymodel
#     ymodel = model.forward(temp, dict_abund, logz, norm, vel)
#   File "/Users/daniela/work/repositories/spexai/spexai/inference/model.py", line 188, in forward
#     output = self.broadening(y.flatten(),  velocity).flatten()
#   File "/Users/daniela/work/repositories/spexai/spexai/inference/model.py", line 134, in broadening
#     normal_matrix_new = normal_matrix_new.to_sparse_csr()
# KeyboardInterrupt
#   0%|                                                  | 2/1000 [00:14<2:02:01,  7.34s/it]
# emcee: Exception while calling your likelihood function:
#   params: [ 5.00552262e+00 -2.00052522e+00  1.00141056e+02  1.20140210e+00
#   1.00005179e+05  1.20019283e+00  9.19639158e-01]
#   args: (tensor([0., 0., 0.,  ..., 0., 0., 0.]), CombinedModel(
#   (models): ModuleDict(
#     (Z1): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z2): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z3): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z4): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z5): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z6): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z7): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z8): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z9): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z10): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z11): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z12): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z13): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z14): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z15): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z16): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z17): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z18): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z19): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z20): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z21): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z22): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z23): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z24): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z25): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z26): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=250, bias=True)
#         (activation0): NonLinear()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=250, out_features=250, bias=True)
#         (activation1): NonLinear()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=250, out_features=250, bias=True)
#         (activation2): NonLinear()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=250, out_features=50125, bias=True)
#       )
#     )
#     (Z27): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z28): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z29): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#     (Z30): FFN(
#       (act_fn): ModuleDict(
#         (sigmoid): Sigmoid()
#         (relu): ReLU()
#         (elu): ELU(alpha=1.0)
#         (softmax): Softmax(dim=None)
#         (sofltpus): Softplus(beta=1, threshold=20)
#         (tanh): Tanh()
#       )
#       (layers): Sequential(
#         (dropout0): Dropout(p=0.0, inplace=False)
#         (linear0): Linear(in_features=1, out_features=150, bias=True)
#         (activation0): Tanh()
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (linear1): Linear(in_features=150, out_features=150, bias=True)
#         (activation1): Tanh()
#         (dropout2): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=150, out_features=150, bias=True)
#         (activation2): Tanh()
#         (dropout3): Dropout(p=0.0, inplace=False)
#         (linear3): Linear(in_features=150, out_features=50125, bias=True)
#       )
#     )
#   )
#   (means): ParameterDict(
#       (Z1): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z2): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z3): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z4): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z5): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z6): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z7): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z8): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z9): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z10): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z11): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z12): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z13): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z14): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z15): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z16): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z17): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z18): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z19): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z20): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z21): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z22): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z23): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z24): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z25): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z26): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z27): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z28): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z29): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z30): Parameter containing: [torch.FloatTensor of size 50125]
#   )
#   (scales): ParameterDict(
#       (Z1): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z2): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z3): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z4): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z5): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z6): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z7): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z8): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z9): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z10): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z11): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z12): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z13): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z14): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z15): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z16): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z17): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z18): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z19): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z20): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z21): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z22): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z23): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z24): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z25): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z26): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z27): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z28): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z29): Parameter containing: [torch.FloatTensor of size 50125]
#       (Z30): Parameter containing: [torch.FloatTensor of size 50125]
#   )
#   (rebin_interp): RebinSpectra_interpolate()
# ))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[600], line 1
# ----> 1 sampler.run_mcmc(initial_pos, 1000, progress=True)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py:443, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     440     initial_state = self._previous_state
#     442 results = None
# --> 443 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444     pass
#     446 # Store so that the ``initial_state=None`` case will work
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py:402, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     399 move = self._random.choice(self._moves, p=self._weights)
#     401 # Propose
# --> 402 state, accepted = move.propose(model, state)
#     403 state.random_state = self.random_state
#     405 if tune:
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/moves/red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py:489, in EnsembleSampler.compute_log_prob(self, coords)
#     487     else:
#     488         map_func = map
# --> 489     results = list(map_func(self.log_prob_fn, p))
#     491 try:
#     492     log_prob = np.array([float(l[0]) for l in results])
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py:624, in _FunctionWrapper.__call__(self, x)
#     622 def __call__(self, x):
#     623     try:
# --> 624         return self.f(x, *self.args, **self.kwargs)
#     625     except:  # pragma: no cover
#     626         import traceback
#
# Cell In[520], line 6, in logprob(param_list, counts, model)
#       3 if not np.isfinite(lp):
#       4     return -np.inf
# ----> 6 ll = loglikelihood(param_list, counts, model)
#       7 lpost = ll + lp
#       8 return lpost.detach().numpy()
#
# Cell In[513], line 28, in loglikelihood(param_list, counts, model)
#      27 def loglikelihood(param_list, counts, model):
# ---> 28     yflux = calculate_ymodel(param_list, model)
#      30     loglike = torch.sum(-yflux + counts * torch.log(yflux) - torch.special.gammaln(counts + 1.))
#      32     if not torch.isfinite(loglike):
#
# Cell In[513], line 22, in calculate_ymodel(param_list, model)
#      20 #counts = torch.tensor(counts, dtype=torch.float32)
#      21 temp = torch.tensor([temp], dtype=torch.float32)
# ---> 22 ymodel = model.forward(temp, dict_abund, logz, norm, vel)
#      23 yflux = ymodel * combined_model.chan_diff * combined_model.exp_time + 1e-30
#      25 return yflux
#
# File ~/work/repositories/spexai/spexai/inference/model.py:188, in CombinedModel.forward(self, temp, abundances, logz, norm, velocity)
#     170 '''
#     171 Calculates the simulated spectra with the NN emulator of the individual elements
#     172
#    (...)
#     184     velocity broading of turbulance [km/sec]
#     185 '''
#     187 y = self.emulator_model(temp, abundances, norm)
# --> 188 output = self.broadening(y.flatten(),  velocity).flatten()
#     189 output = self.rebin_interp(output.flatten(),  10**logz).flatten()*norm
#     190 output = torch.mul(output, self.arf)
#
# File ~/work/repositories/spexai/spexai/inference/model.py:134, in CombinedModel.broadening(self, spectrum, velocity)
#     131 #normalisation = torch.sparse_coo_tensor(combined_model.diag_index, normalisation_values_csr, shape).to_sparse_csr()
#     132 #normal_matrix_new = torch.sparse.mm(normalisation.to(spectrum.device), normal_matrix.to(spectrum.device)).cpu()
#     133 normal_matrix_new = normal_matrix.to_sparse_coo() * normalisation_values[:,None]
# --> 134 normal_matrix_new = normal_matrix_new.to_sparse_csr()
#     136 #convolve the normal distributions with the spectrum
#     137 spectrum_dx = spectrum.view(-1,1)*self.e_diff.view(-1,1).to(spectrum.device)
#
# KeyboardInterrupt:

# %%
labels = list(params.keys())
print(labels)

fig, axes = plt.subplots(ndim, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");
# Out:
# ['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14']
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure()
plt.hist(initial_pos[:,1])
# Out:
# /var/folders/cm/2d1tk8fs125435tgbw22nb0h0000gp/T/ipykernel_84236/2299327707.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# <img src="data:image/png;base64,..." width="640">
# (array([2., 1., 3., 3., 3., 1., 3., 2., 0., 2.]),
#  array([-0.00488316, -0.00396663, -0.0030501 , -0.00213357, -0.00121704,
#         -0.00030051,  0.00061602,  0.00153255,  0.00244908,  0.00336561,
#          0.00428214]),
#  <BarContainer object of 10 artists>)

# %%
flat_samples = sampler.get_chain(discard=600, thin=10, flat=True)
fig = plt.figure(figsize=(8,8))
corner.corner(flat_samples, fig=fig, labels = list(params.keys()),
              truths=list(true_params.values()))
# Out:
# <img src="data:image/png;base64,..." width="800">
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# <img src="data:image/png;base64,..." width="800">

# %%
flat_samples = sampler.get_chain(discard=600, thin=10, flat=True)
flat_lnprob = sampler.get_log_prob(discard=600, thin=10, flat=True)

# %%
plt.figure()
plt.scatter(flat_samples[:,-1], flat_lnprob)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sampler.flatlnprobability
# Out:
# array([-9.99999980e+10, -9.99999980e+10, -9.99999980e+10, ...,
#        -1.05259438e+05, -9.99999980e+10, -1.05378234e+05])

# %% [markdown]
# ### Modelling with Dynesty

# %%
fit.prior
# Out:
# {'temp': {'mu': 5, 'sigma': 2},
#  'met': {'mu': 1, 'sigma': 0.3},
#  'vel': {'mu': 100, 'sigma': 50},
#  'logz': {'mu': -3, 'sigma': 1},
#  'norm': {'mu': 10000.0, 'sigma': 1000.0},
#  'Z8': {'mu': 1, 'sigma': 0.3},
#  'Z14': {'mu': 1, 'sigma': 0.3}}

# %%
import dynesty

# %%
params.keys()
# Out:
# dict_keys(['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14'])

# %%
import scipy.stats 

def loglike(param_values):
    keys = ['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14']
    params = fit.flat_to_nested_dict(dict(zip(keys, param_values)))
    return float(fit.log_likelihood(params))

def prior_transform(u):
    
    keys = ['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14']
    x = np.zeros_like(u)
  
    #intial guess and prior for fit
    prior = {
            'temp': {'mu': 5,    'sigma': 0.5},
            'met' : {'mu': 1,    'sigma': .2},
            'vel' : {'mu': 100,  'sigma': 10},
            'logz': {'mu': -3,   'sigma': 1},
            'norm': {'mu': 1e4, 'sigma':1e3},
            'Z8':{'mu':1, 'sigma':.2},
            'Z14':{'mu':1, 'sigma':.2}
        }
  
    for i,key in enumerate(keys):
        x[i] = scipy.stats.norm(prior[key]["mu"], prior[key]["sigma"]).ppf(u[i])
    
    return x

# %%
params
# Out:
# {'temp': 5,
#  'logz': -2,
#  'vel': 100,
#  'met': 1.2,
#  'norm': 10000.0,
#  'Z8': 1.2,
#  'Z14': 0.9}

# %% [markdown]
# Let's check whether the prior transform works correctly:

# %%
ndim = len(params)
nsamples = 1000

uall = np.random.uniform(size=(nsamples, ndim))

xall = []

for u in uall:
    xall.append(prior_transform(u))
    
xall = np.array(xall)
    
fig, axes = plt.subplots(2, 4, figsize=(8,6))

axes = np.hstack(axes)

for i in range(ndim):
    axes[i].hist(xall[:,i], bins=100, histtype="stepfilled", alpha=0.6)
    axes[i].set_title(list(params.keys())[i])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Now we can try to run the sampling:

# %%
sampler = dynesty.DynamicNestedSampler(loglike, prior_transform, ndim,
                                       bound='balls', sample='rwalk')

# %%
sampler.run_nested()
# Out:
# 3310it [5:24:38,  5.09s/it, batch: 0 | bound: 21 | nc: 27 | ncall: 59103 | eff(%):  5.553 | loglstar:   -inf < -55114.656 <    inf | logz: -55127.385 +/-  0.157 | dlogz: 1513.735 >  0.010]  Traceback (most recent call last):
#   File "/opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/dynesty.py", line 910, in __call__
#     return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#   File "/var/folders/cm/2d1tk8fs125435tgbw22nb0h0000gp/T/ipykernel_84236/3925438096.py", line 6, in loglike
#     return float(fit.log_likelihood(params))
#   File "/Users/daniela/work/repositories/spexai/spexai/inference/fit_new.py", line 246, in log_likelihood
#     ymodel = self.combined_model(temp, dict_abund, params['logz'],  params['norm'], params['vel'])
#   File "/opt/miniconda3/envs/spexai/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/daniela/work/repositories/spexai/spexai/inference/model.py", line 188, in forward
#     output = self.broadening(y.flatten(),  velocity).flatten()
#   File "/Users/daniela/work/repositories/spexai/spexai/inference/model.py", line 134, in broadening
#     normal_matrix_new = normal_matrix_new.to_sparse_csr()
# KeyboardInterrupt
# 3310it [5:24:39,  5.89s/it, batch: 0 | bound: 21 | nc: 27 | ncall: 59103 | eff(%):  5.553 | loglstar:   -inf < -55114.656 <    inf | logz: -55127.385 +/-  0.157 | dlogz: 1513.735 >  0.010]
# Exception while calling loglikelihood function:
#   params: [ 4.58827292e+00 -2.00570087e+00  1.08196752e+02  9.96529350e-01
#   1.07394020e+04  6.50723619e-01  1.11608508e+00]
#   args: []
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[264], line 1
# ----> 1 sampler.run_nested()
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/dynamicsampler.py:2043, in DynamicSampler.run_nested(self, nlive_init, maxiter_init, maxcall_init, dlogz_init, logl_max_init, n_effective_init, nlive_batch, wt_function, wt_kwargs, maxiter_batch, maxcall_batch, maxiter, maxcall, maxbatch, n_effective, stop_function, stop_kwargs, use_stop, save_bounds, print_progress, print_func, live_points, resume, checkpoint_file, checkpoint_every)
#    2041 try:
#    2042     if not self.base:
# -> 2043         for results in self.sample_initial(
#    2044                 nlive=nlive_init,
#    2045                 dlogz=dlogz_init,
#    2046                 maxcall=maxcall_init,
#    2047                 maxiter=maxiter_init,
#    2048                 logl_max=logl_max_init,
#    2049                 live_points=live_points,
#    2050                 n_effective=n_effective_init,
#    2051                 resume=resume,
#    2052                 save_samples=True):
#    2053             if resume:
#    2054                 resume = False
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/dynamicsampler.py:1330, in DynamicSampler.sample_initial(self, nlive, update_interval, first_update, maxiter, maxcall, logl_max, dlogz, n_effective, live_points, save_samples, resume)
#    1328     self.internal_state = DynamicSamplerStatesEnum.LIVEPOINTSINIT
#    1329     # Run the sampler internally as a generator.
# -> 1330 for it, results in enumerate(
#    1331         self.sampler.sample(maxiter=maxiter,
#    1332                             save_samples=save_samples,
#    1333                             maxcall=maxcall,
#    1334                             logl_max=logl_max,
#    1335                             dlogz=dlogz,
#    1336                             resume=resume)):
#    1337     # Grab results.
#    1338
#    1339     # Save our base run (which we will use later).
#    1340     add_info = dict(id=results.worst,
#    1341                     u=results.ustar,
#    1342                     v=results.vstar,
#    (...)
#    1354                     bounditer=results.bounditer,
#    1355                     scale=self.sampler.scale)
#    1357     self.base_run.append(add_info)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampler.py:840, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples, resume)
#     835     old_blob = None
#     837 # Sample a new live point from within the likelihood constraint
#     838 # `logl > loglstar` using the bounding distribution and sampling
#     839 # method from our sampler.
# --> 840 u, v, logl, nc = self._new_point(loglstar_new)
#     841 ncall += nc
#     842 self.ncall += nc
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampler.py:421, in Sampler._new_point(self, loglstar)
#     418 ncall_accum = 0
#     419 while True:
#     420     # Get the next point from the queue
# --> 421     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     422     ncall += nc
#     423     ncall_accum += nc
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampler.py:404, in Sampler._get_point_value(self, loglstar)
#     402 # If the queue is empty, refill it.
#     403 if self.nqueue <= 0:
# --> 404     self._fill_queue(loglstar)
#     406 # Grab the earliest entry.
#     407 u, v, logl, nc, blob = self.queue.pop(0)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampler.py:397, in Sampler._fill_queue(self, loglstar)
#     387 for i in range(self.queue_size):
#     388     args.append(
#     389         SamplerArgument(u=point_queue[i],
#     390                         loglstar=loglstar,
#    (...)
#     395                         rseed=seeds[i],
#     396                         kwargs=self.kwargs))
# --> 397 self.queue = list(mapper(evolve_point, args))
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampling.py:149, in sample_rwalk(args)
#     147 # Unzipping.
#     148 rstate = get_random_generator(args.rseed)
# --> 149 return generic_random_walk(args.u, args.loglstar, args.axes, args.scale,
#     150                            args.prior_transform, args.loglikelihood,
#     151                            rstate, args.kwargs)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/sampling.py:248, in generic_random_walk(u, loglstar, axes, scale, prior_transform, loglikelihood, rstate, kwargs)
#     246 # Check proposed point.
#     247 v_prop = prior_transform(u_prop)
# --> 248 logl_prop = loglikelihood(v_prop)
#     249 ncall += 1
#     251 if logl_prop > loglstar:
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/utils.py:187, in LogLikelihood.__call__(self, x)
#     183 def __call__(self, x):
#     184     """
#     185     Evaluate the likelihood f-n once
#     186     """
# --> 187     ret = LoglOutput(self.loglikelihood(x), self.blob)
#     188     if self.save:
#     189         self.history_append([ret.val], [x])
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/dynesty/dynesty.py:910, in _function_wrapper.__call__(self, x)
#     902 def __call__(self, x):
#     903     try:
#     904         # IMPORTANT
#     905         # Here we make a copy if the input vector just to ensure
#    (...)
#     908         # This comes at performance cost, but it's worthwhile
#     909         # as it may lead to hard to diagnose weird behaviour
# --> 910         return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#     911     except:  # noqa
#     912         print(f"Exception while calling {self.name} function:")
#
# Cell In[260], line 6, in loglike(param_values)
#       4 keys = ['temp', 'logz', 'vel', 'met', 'norm', 'Z8', 'Z14']
#       5 params = fit.flat_to_nested_dict(dict(zip(keys, param_values)))
# ----> 6 return float(fit.log_likelihood(params))
#
# File ~/work/repositories/spexai/spexai/inference/fit_new.py:246, in SingleTemp.log_likelihood(self, params)
#     243 #calculate spectra with NN
#     245 with torch.no_grad():
# --> 246     ymodel = self.combined_model(temp, dict_abund, params['logz'],  params['norm'], params['vel'])
#     248 mu = ymodel[self.intv]*self.chan_diff*self.combined_model.exp_time+1e-30
#     250 ps = Poisson(mu)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/repositories/spexai/spexai/inference/model.py:188, in CombinedModel.forward(self, temp, abundances, logz, norm, velocity)
#     170 '''
#     171 Calculates the simulated spectra with the NN emulator of the individual elements
#     172
#    (...)
#     184     velocity broading of turbulance [km/sec]
#     185 '''
#     187 y = self.emulator_model(temp, abundances, norm)
# --> 188 output = self.broadening(y.flatten(),  velocity).flatten()
#     189 output = self.rebin_interp(output.flatten(),  10**logz).flatten()*norm
#     190 output = torch.mul(output, self.arf)
#
# File ~/work/repositories/spexai/spexai/inference/model.py:134, in CombinedModel.broadening(self, spectrum, velocity)
#     131 #normalisation = torch.sparse_coo_tensor(combined_model.diag_index, normalisation_values_csr, shape).to_sparse_csr()
#     132 #normal_matrix_new = torch.sparse.mm(normalisation.to(spectrum.device), normal_matrix.to(spectrum.device)).cpu()
#     133 normal_matrix_new = normal_matrix.to_sparse_coo() * normalisation_values[:,None]
# --> 134 normal_matrix_new = normal_matrix_new.to_sparse_csr()
#     136 #convolve the normal distributions with the spectrum
#     137 spectrum_dx = spectrum.view(-1,1)*self.e_diff.view(-1,1).to(spectrum.device)
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(2, 4, figsize=(8,6))

axes = np.hstack(axes)

for i in range(ndim):
    key = list(params.keys())[i]
    axes[i].hist(sampler.results.samples[:,i], bins=100, histtype="stepfilled", alpha=0.6)
    axes[i].set_title(key)
    axes[i].axvline(params[key], lw=2, color="red")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
l = float(loglike(test_params))

# %% [markdown]
# __Add aditional parameters__
#
# Single element abundace that differ with respect to the overall metalicity and Iron can be added in as extra parameter(s).
# These are writen in the format ```'ZX'``` with ```X``` the atom number of the elements. ```add_prior``` gives the prior and intial  values of the added paramater(s).

# %%
#names of aditional fitted parameters 
add_prior = {'Z8':{'mu':1, 'sigma':.3},'Z14':{'mu':1, 'sigma':.3}}

# %% [markdown]
# ### Run Ensemble Sampler Fit
#
# Then after ensemble sampler has been fully intialized the data can be fitted with ```Fit.fit_spectra``` making use of ```emcee``` algorithm.
# ```Fit.fit_spectra``` will also print the integrated autocorrelation time to give an indication of the burn-in time.

# %%
#intial guess and prior for fit
full_prior = {
        'temp': {'mu': 5,    'sigma': 1},
        'met' : {'mu': 1.2,    'sigma': .1},
        'vel' : {'mu': 100,  'sigma': 50},
        'logz': {'mu': -2,   'sigma': 0.5},
        'norm': {'mu': 1e4, 'sigma':1e3},
        'Z8':{'mu':1.2, 'sigma':.1},
        'Z14':{'mu':0.9, 'sigma':.1}
        }

# %%
#initialize thes
fit = spexai.inference.fit_new.SingleTemp(torch.Tensor(counts), combined_model, full_prior,
                 e_min=None, e_max=15.0, fdir_nn='neuralnetworks/')
# Out:
# Using cpu

# %%
np.seterr(all="ignore") #ignore RuntimeWarning error prints
fit.fit_spectrum(20, 1000)
# Out:
# (20, 7)
# 100%|███████████████████████████████████████████████| 1000/1000 [1:08:33<00:00,  4.11s/it]
# ---------------------------------------------------------------------------
# AutocorrError                             Traceback (most recent call last)
# Cell In[326], line 2
#       1 np.seterr(all="ignore") #ignore RuntimeWarning error prints
# ----> 2 fit.fit_spectrum(20, 1000)
#
# File ~/work/repositories/spexai/spexai/inference/fit_new.py:191, in SingleTemp.fit_spectrum(self, nwalkers, nsteps)
#     189 print(initialpos.shape)
#     190 self.sampler.run_mcmc(initialpos, nsteps=self.nsteps,  progress=True, store=True)
# --> 191 print(self.sampler.get_autocorr_time())
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/ensemble.py:605, in EnsembleSampler.get_autocorr_time(self, **kwargs)
#     604 def get_autocorr_time(self, **kwargs):
# --> 605     return self.backend.get_autocorr_time(**kwargs)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/backends/backend.py:150, in Backend.get_autocorr_time(self, discard, thin, **kwargs)
#     131 """Compute an estimate of the autocorrelation time for each parameter
#     132
#     133 Args:
#    (...)
#     147
#     148 """
#     149 x = self.get_chain(discard=discard, thin=thin)
# --> 150 return thin * autocorr.integrated_time(x, **kwargs)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/emcee/autocorr.py:112, in integrated_time(x, c, tol, quiet)
#     110     msg += "N/{0} = {1:.0f};\ntau: {2}".format(tol, n_t / tol, tau_est)
#     111     if not quiet:
# --> 112         raise AutocorrError(tau_est, msg)
#     113     logger.warning(msg)
#     115 return tau_est
#
# AutocorrError: The chain is shorter than 50 times the integrated autocorrelation time for 7 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 20;
# tau: [ 86.27857088  61.09668365 102.9354286   91.41535435 107.23948613
#  106.61761393  83.15500726]

# %% [markdown]
# ### Evaluating the fit results
#
# The progress of the walker can be visualized in a timeseries giving the parameter values for each walker at each step in the chain.

# %%
fit.plot_timeseries()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %% [markdown]
# The results of the fit can visualized with a cornerplot. ```Fit.cornerplot``` is also able to save the sampled posterior in an .csv format by giving a directory name ```fitdir```.  In this example you discard the first ```100``` steps in the chain ```discard``` and only reading every 15th step ```thin```. The corner plot can also be oveploted with the true values of the parameters by giving a list ```true_values```, where the values shoud be same order as the prior.

# %%
import corner

# %%
fit.sampler.chain.shape
# Out:
# (20, 1000, 7)

# %%
flatchain = fit.sampler.chain[:,500:, :].reshape((20*500,7))

# %%
corner.corner(flatchain);
# Out:
# <img src="data:image/png;base64,..." width="1600">
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %%
fit.sampler.flatchain
# Out:
# array([[5.50790899e+00, 1.28269373e+00, 1.02171935e+02, ...,
#         9.21158030e+03, 7.68538758e-01, 1.08074851e+00],
#        [5.40441118e+00, 1.14223986e+00, 9.42690448e+01, ...,
#         9.15721252e+03, 9.58856044e-01, 8.97665854e-01],
#        [5.15327538e+00, 1.33447562e+00, 1.03851004e+02, ...,
#         8.76078877e+03, 1.12967959e+00, 9.53527762e-01],
#        ...,
#        [4.99755108e+00, 1.20332933e+00, 1.01675310e+02, ...,
#         9.98233205e+03, 1.17251501e+00, 9.37580718e-01],
#        [5.55352480e+00, 2.87033238e-01, 1.23713685e+02, ...,
#         1.19222328e+04, 8.54605489e-01, 9.97505709e-01],
#        [4.97124597e+00, 1.19280225e+00, 9.82025274e+01, ...,
#         9.98107961e+03, 1.21270306e+00, 9.36459532e-01]])

# %%
#true_val = [temp,   met,    vel,    logz    norm,   Z8,    Z14]
true_val =  [5,      1,      100,    -2,     1e10,   1.2,   0.9]

fit.cornerplot(600, thin=10, fitdir=None, true_values=true_val)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1750">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[333], line 4
#       1 #true_val = [temp,   met,    vel,    logz    norm,   Z8,    Z14]
#       2 true_val =  [5,      1,      100,    -2,     1e10,   1.2,   0.9]
# ----> 4 fit.cornerplot(600, thin=10, fitdir=None, true_values=true_val)
#
# File ~/work/repositories/spexai/spexai/inference/fit_new.py:357, in SingleTemp.cornerplot(self, discard, fitdir, thin, true_values)
#     355 g = sns.PairGrid(self.df, diag_sharey=False, corner=True, layout_pad=0.25, despine=False)
#     356 # g.map_lower(sns.scatterplot,  size=.2)
# --> 357 g.map_lower(sns.kdeplot, cmap="Blues")
#     358 g.map_diag(sns.histplot, stat='density')
#     359 g.map_diag(sns.kdeplot,  color="k")
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/axisgrid.py:1389, in PairGrid.map_lower(self, func, **kwargs)
#    1378 """Plot with a bivariate function on the lower diagonal subplots.
#    1379
#    1380 Parameters
#    (...)
#    1386
#    1387 """
#    1388 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1389 self._map_bivariate(func, indices, **kwargs)
#    1390 return self
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/axisgrid.py:1568, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1566     if ax is None:  # i.e. we are in corner mode
#    1567         continue
# -> 1568     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1569 self._add_axis_labels()
#    1571 if "hue" in signature(func).parameters:
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/axisgrid.py:1609, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1605 if "hue" not in kwargs:
#    1606     kwargs.update({
#    1607         "hue": hue, "hue_order": self._hue_order, "palette": self._orig_palette,
#    1608     })
# -> 1609 func(x=x, y=y, **kwargs)
#    1611 self._update_legend_data(ax)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/distributions.py:1731, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    (...)
#    1726         **plot_kws,
#    1727     )
#    1729 else:
# -> 1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    1734         levels=levels,
#    1735         thresh=thresh,
#    1736         legend=legend,
#    1737         color=color,
#    1738         warn_singular=warn_singular,
#    1739         cbar=cbar,
#    1740         cbar_ax=cbar_ax,
#    1741         cbar_kws=cbar_kws,
#    1742         estimate_kws=estimate_kws,
#    1743         **kwargs,
#    1744     )
#    1746 return ax
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/distributions.py:1081, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1079 try:
#    1080     if not singular:
# -> 1081         density, support = estimator(*observations, weights=weights)
#    1082 except np.linalg.LinAlgError:
#    1083     # Testing for 0 variance doesn't catch all cases where scipy raises,
#    1084     # but we can also get a ValueError, so we need this convoluted approach
#    1085     singular = True
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/_statistics.py:194, in KDE.__call__(self, x1, x2, weights)
#     192     return self._eval_univariate(x1, weights)
#     193 else:
# --> 194     return self._eval_bivariate(x1, x2, weights)
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/seaborn/_statistics.py:185, in KDE._eval_bivariate(self, x1, x2, weights)
#     182 else:
#     184     xx1, xx2 = np.meshgrid(*support)
# --> 185     density = kde([xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)
#     187 return density, support
#
# File /opt/miniconda3/envs/spexai/lib/python3.10/site-packages/scipy/stats/_kde.py:268, in gaussian_kde.evaluate(self, points)
#     265         raise ValueError(msg)
#     267 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 268 result = gaussian_kernel_estimate[spec](
#     269     self.dataset.T, self.weights[:, None],
#     270     points.T, self.cho_cov, output_dtype)
#     272 return result[:, 0]
#
# KeyboardInterrupt:

# %% [markdown]
# The fit results can be directly compared to the data by overplotting the fitted model with parameters drawn from the posterior to the observed data, the number of samples it overplots is given by ```nsample```. Also prints the mean and 1-sigma interval of the fitted parameters.

# %%
'''This step can take a long time to run'''
fit.plot_spectrum(nsample=20)
# Out:
# <img src="data:image/png;base64,..." width="2000">
# temp = 6.172154543411173_(-0.012595587305946232)^(+3.7864435245307337)
# met = 7.066252756861859_(-2.5090707661528038)^(+0.01684993981179339)
# vel = 128.22946340311987_(-30.834856211661375)^(+2.6799458056247545)
# logz = -1.9994613979955655_(-7.906423946271994)^(+0.00011349716843711555)
# norm = 28017.03090921147_(-22.124707820668846)^(+11538.776233660457)
# Z8 = 7.693597980592035_(-0.027118104868313786)^(+1.369714968113831)
# Z14 = 0.6639454600390278_(-0.6626594834473498)^(+0.00823185180885333)

# %% [markdown]
# ## Fitting a Two-Temperature Model
#
# Simulated data or real data can be model with a one temperuture model by  ```TwoTemp``` a subclass of Fit
#
# The paramater that are fitted are the
# - First temperature in KeV  ```temp1``` (between 0.2 and 10 KeV)
# - Second temperature in KeV  ```temp2``` (between 0.2 and 10 KeV)
# - Metalicity [Z_solar] ```met```  (larger then 0)
# - Turbulent velocity in km/sec ```vel``` (between 0 and 600 km/sec)
# - Redshift in log10(z) ```logz``` (between -10 and 1)
# - First normalisation ```norm1``` (between 1e5 and 1e15)
# - Second normalisation ```norm2``` (between 1e5 and 1e15)
#
# Additional parameter(s)
# - Single element ```X``` abundace ratio with respect to Iron ```ZX```, where ```X``` is tha atom number (larger then 0)
#
# The intial guess with there standard diviation of all the parameters that are fitted can be put into the dictiornary of the ```prior```.

# %%
#intial guess and prior for fit
prior = {
        'temp1': {'mu': 4.5,    'sigma': 2},
        'temp2': {'mu': 6,    'sigma': 2},
        'met' : {'mu': 1,    'sigma': .3},
        'vel' : {'mu': 100,  'sigma': 50},
        'logz': {'mu': -5,   'sigma': 2},
        'norm1': {'mu': 1e10, 'sigma': 5e9},
        'norm2': {'mu': 1.5e10, 'sigma': 5e9}
        }

# %% [markdown]
# The ensemble samper can be intialized with ```nwalkers``` and ```nsteps``` for the walker to go through, ```prior``` indicates the intial values for the parameters and there Gaussion prior in the likelihood, other parameter that can be initialized are the Luminosity Distance in m and the energy interval of the spectrum in KeV (```e_min``` > 0.1; ```e_max``` < 25).
#
# ```fdir_nn``` is the file directory to the trained neural networks and should match the path on your device.

# %%
#initialize the
fit_2t = TwoTemp(50, 800, prior, Luminosity_Distance=1e25, fdir_nn='/home/jmatthijss/spexai_code/neuralnetworks/', e_max=15)

# %% [markdown]
# ### Reading in the FITS files
#
# To be able to fit real data the response of the telescope can be read in by the FITS file, for the Response Matrix File (RMF), effective area response file (ARF).
#
# The data used for fitting can be read in from a FITS file of the observed data ```TwoTemp.load_data```, or can be simulated by the model with ```TwoTemp.sim_data(params)``` here ```params``` is a dictornary with the parameter names and there values.
#
# In addition the response files there is a sparse matrix (```make_sparsex```) used for convulation that implements line broadening to the spectra. The speed an accuracy of the line broadening is strongly dependent on the kernel size of the convulolution ```n``` and the default ```n=300```, increasing ```n``` will make the line-broading more accurete but will also segnifcanly impact the speed.

# %%
'''This step can take a long time to run'''
#reading in the response matrix file
fit_2t.combined_model.load_rm('/home/jmatthijss/obs234_HP_obs234_all_det/obs234_HP_obs234_all_det_he.rmf')

# %%
#reading in the effective area
fit_2t.combined_model.load_arf('/home/jmatthijss/obs234_HP_obs234_all_det/obs234_HP_obs234_all_det_point_he.arf')

# %%
'''This step can take a long time to run'''
#initializing the sparse matrix for the convolution from line-broadening
fit_2t.combined_model.load_sparsematrix_x(n=200)

# %%
#create your own data
params = {'temp1':4, 'temp2':5.8, 'logz':-2, 'vel':100, 'met':1.2, 'norm1':8e9, 'norm2':1.2e10}
fit_2t.sim_data(params, exp_time=50000)

# %% [markdown]
# __Add aditional parameters__
#
# Single element abundace that differ with respect to the overall metalicity and Iron can be added in as extra parameter(s).
# These are writen in the format ```'ZX'``` with ```X``` the atom number of the elements. ```add_prior``` gives the prior and intial  values of the added paramater(s).

# %%
#names of aditional fitted parameters 
add_prior = {'Z8':{'mu':1, 'sigma':.3},'Z14':{'mu':1, 'sigma':.3}}

# %% [markdown]
# ### Run Ensemble Sampler Fit
#
# Then after ensemble sampler has been fully intialized the data can be fitted with ```Fit.fit_spectra``` making use of ```emcee``` algorithm.
# ```TwoTemp.fit_spectra``` will also print the integrated autocorrelation time to give an indication of the burn-in time.

# %%
'''This step can take a long time to run'''
np.seterr(all="ignore")#ignore RuntimeWarning error prints
fit_2t.fit_spectra(add_prior=add_prior)

# %% [markdown]
# ### Evaluating the fit results
#
# The progress of the walker can be visualized in a timeseries giving the parameter values for each walker at each step in the chain.

# %%
fit_2t.plot_timeseries()

# %% [markdown]
# The results of the fit can visualized with a cornerplot. ```TwoTemp.cornerplot``` is also able to save the sampled posterior in an .csv format by giving a directory name ```fitdir```.  In this example you discard the first ```100``` steps in the chain ```discard``` and only reading every 15th step ```thin```. The corner plot can also be oveploted with the true values of the parameters by giving a list ```true_values```, where the values shoud be same order as the prior.

# %%
#true_val = [temp1, temp2,  met,    vel,    logz    norm1,  norm2,  Z8,    Z14]
true_val =  [4,     5.8,    1,      100,    -2,     8e9,    1.2e10, 1.2,   0.9]

fit_2t.cornerplot(600, thin=10, fitdir=None, true_values=true_val)

# %% [markdown]
# The fit results can be directly compared to the data by overplotting the fitted model with parameters drawn from the posterior to the observed data, the number of samples it overplots is given by ```nsample```. Also prints the mean and 1-sigma interval of the fitted parameters.

# %%
'''This step can take a long time to run'''
fit_2t.plot_spectrum(nsample=20)

# %% [markdown]
# ## Fitting a Multi-Temperature Distribution Model
#
# This uses a Subclass of ```Fit```, ```TempDist``` to fit a model with a multi-temperature distribution.
#
# The temperature need to give a function that outputs a temperature grid and temperature distribution described by parameters. The output of the temperature grid should always be inbetween 0.2 and 10 KeV and linearly spaced and the distribution should always be normalized.
#
# In this exapmle we look at a Normal Distribution for our temperature distribution, parametrized by a mean temperature and standard devitation.
#
# The paramater that are fitted
# - Mean Temperature in KeV ```mean_temp``` (between 0.2 and 10)
# - Standard divation of Temperature in log(KeV) ```log_sd_temp``` (between -5, 0.3)
# - Metalicity [Z_solar] ```met```  (larger then 0)
# - Turbulent velocity in km/sec ```vel``` (between 0 and 600 km/sec)
# - Redshift in log10(z) ```logz``` (between -10 and 1)
# - Normalisation ```norm``` (between 1e5 and 1e15)
#
# Additional parameter(s)
# - Single element ```X``` abundace ratio with respect to Iron ```ZX```, where ```X``` is tha atom number (larger then 0)
#
# The intial guess with there standard diviation can be put into the dictiornary of the ```prior```.

# %%
def normal_dist(params):
    '''
    Normal Distribution with stdev in logspace
    Parameters
    ----------
    params: dict
        dictionary with the keys of distribution parameters
        in this case 'mean_temp' and 'log_sd_temp'
    '''
    #intialize temperature grid
    low = max(params['mean_temp']-5*10**params['log_sd_temp'], 0.2)
    high = min(params['mean_temp']+5*10**params['log_sd_temp'], 10)
    temp_grid = np.linspace(low, high,  500)
    
    #Gaussion distribution
    mean = params['mean_temp']
    sd = 10**params['log_sd_temp']
    temp_dist = 1/(np.sqrt(2*np.pi)*sd**2) * np.exp(-0.5*((temp_grid-mean)/sd)**2)
    
    #normalize the function 
    temp_dist = temp_dist/np.sum(temp_dist*np.mean(np.diff(temp_grid)))
    return temp_grid, temp_dist

#define allowed interval of parameter of the distribution
interval = {
            'mean_temp': [0.2,10],
            'log_sd_temp'  : [-5, 0.3]
           }

# %% [markdown]
# The intial guess with there standard diviation of all the parameters that are fitted can be put into the dictiornary of the ```prior```.

# %%
#intial guess and prior for temp run
prior = {
        'mean_temp': {'mu': 4, 'sigma': 1},
        'log_sd_temp'  : {'mu': 0, 'sigma': 1},
        'met'      : {'mu': 0.6, 'sigma': .3},
        'vel'      : {'mu': 160, 'sigma': 25},
        'logz'     : {'mu': np.log10(0.017284),  'sigma': 0.05},
        'norm'     : {'mu': 2e10, 'sigma': 1e9}
        }

# %% [markdown]
# The ensemble samper can be intialized with ```nwalkers``` and ```nsteps``` for the walker to go through, the prior ```prior```, for the TempDist we need to give the function that returns a normalized temperature distribution with the temperature grid ```normal_dist``` and the bound interval of this ditributions parameter ```interval```, other parameter that can be initialized are the Luminosity Distance in m and the energy interval of the spectrum in KeV (```e_min, e_max```).

# %%
#initialize the
fit_dist = TempDist(40, 2, prior, normal_dist, interval, Luminosity_Distance=9.461e24, e_min=2, e_max=9, fdir_nn='/home/jmatthijss/spexai_code/neuralnetworks/')

# %% [markdown]
# ### Reading in the FITS files
#
# To be able to fit real data the response of the telescope can be read in by the FITS file, for the Response Matrix File (RMF), effective area response file (ARF) and the FITS file of the observed data.
#
# In addition the response files there is a sparse matrix (```make_sparsex```) used for convulation that implements line broadening to the spectra. The speed an accuracy of the line broadening is strongly dependent on the kernel size of the convulolution ```n``` and the default ```n=300```, increasing ```n``` will make the line-broading more accurete but will also segnifcanly impact the speed.

# %%
'''This step can take a long time to run'''
#reading in the response matrix file
fit_dist.combined_model.load_rm('/home/jmatthijss/obs234_HP_obs234_all_det/obs234_HP_obs234_all_det_he.rmf')

# %%
#reading in the effective area
fit_dist.combined_model.load_arf('/home/jmatthijss/obs234_HP_obs234_all_det/obs234_HP_obs234_all_det_point_he.arf')

# %%
'''This step can take a long time to run'''
#initializing the sparse matrix for the convolution from line-broadening
fit_dist.combined_model.load_sparsematrix_x(n=200)

# %% [markdown]
# Now instead of simulating the data we are reading it in from a FITS file

# %%
#reading in the data
fit_dist.load_data('/home/jmatthijss/obs234_HP_obs234_all_det/obs234_HP_obs234_all_det_valign_gcor_he.pi')

# %% [markdown]
# #### Add aditional parameters
#
# Single element abundace that differ with respect to the overall metalicity and Iron can be added in as extra parameter(s).
# These are writen in the format ```'ZX'``` with ```X``` the atom number of the elements. ```add_prior``` gives the prior and intial  values of the added paramater(s).

# %%
#names of aditional fitted parameters 
add_prior = {'Z8':{'mu':1, 'sigma':.3},'Z14':{'mu':1, 'sigma':.3}}

# %% [markdown]
# Then after ensemble sampler has been fully intialized the data can be fitted with ```TempDist.fit_spectra``` making use of ```emcee``` algorithm.
# ```TempDist.fit_spectra``` will aslo print the the integrated autocorrelation time to give an indication of the burn-in time.

# %%
import torch
import matplotlib.pyplot as plt
def normal_dist(x , mean , sd):
    sd = torch.tensor(sd, dtype=torch.float32, device=x.device)
    prob_density = 1/(torch.sqrt(torch.tensor(2*np.pi, dtype=torch.float32, device=x.device)*sd**2)) * torch.exp(-0.5*((x-torch.tensor(mean, dtype=torch.float32, device=x.device))/sd)**2)
    return prob_density

# %%
params = {'Temperature [KeV]': 4, 'Temp Stdev log[KeV]': -2, 'Redshift [log(z)]': np.log10(0.017284), 'Velocity [km/sec]': 160, 'Metalicity [Fe/H]': .7, 'Normalisation': 2e10}

dict_abund = {}
for i in torch.arange(6,31):
    dict_abund[f'Z{i}'] = params['Metalicity [Fe/H]']
    for key in params.keys():
        if key == f'Z{i} [Z{i}/Fe]':
            dict_abund[f'Z{i}'] = params['Metalicity [Fe/H]']*params[f'Z{i} [Z{i}/Fe]']
low = max(params['Temperature [KeV]']-5*10**params['Temp Stdev log[KeV]'], 0.1)
high = min(params['Temperature [KeV]']+5*10**params['Temp Stdev log[KeV]'],10)
temp_grid = torch.linspace(low, high, 500, dtype=torch.float32, device='cuda')
temp_dist = normal_dist(temp_grid, params['Temperature [KeV]'], 10**params['Temp Stdev log[KeV]'])
temp_dist = temp_dist/torch.sum(temp_dist*torch.mean(torch.diff(temp_grid)))
with torch.no_grad():
    ymodel = fit_dist.combined_model(temp_grid, temp_dist, dict_abund, params['Redshift [log(z)]'], 
                    params['Normalisation'], params['Velocity [km/sec]'])
plt.plot(ymodel[fit_dist.intv].cpu().detach())
plt.yscale('log')
plt.ylim(1e-2,1e1)

# %%
'''This step can take a long time to run'''
np.seterr(all="ignore")#ignore RuntimeWarning error prints
fit_dist.fit_spectra(add_prior=add_prior)

# %% [markdown]
# ### Evaluating the fit results
#
# The progress of the walker can be visualized in a timeseries giving the parameter values for each walker at each step in the chain.

# %%
fit_dist.plot_timeseries()

# %% [markdown]
# The results of the fit can visualized with a cornerplot. ```TempDist.cornerplot``` is also able to save the sampled posterior in an .csv format by giving a directory name ```fitdir```.  In this example you discard the first ```100``` steps in the chain ```discard``` and only reading every 15th step ```thin```. The corner plot can also be oveploted with the true values of the parameters by giving a list ```true_values```, where the values shoud be same order as the prior.

# %%
#true_val = mean_temp,  log_sd_temp,    met,    vel,    logz    norm,   Z8, Z14

fit_dist.cornerplot(1, thin=1, fitdir=None, true_values=None)

# %% [markdown]
# The fit results can be directly compared to the data by overplotting the fitted model with parameters drawn from the posterior to the observed data, the number of samples it overplots is given by ```nsample```. Also prints the mean and 1-sigma interval of the fitted parameters.

# %%
'''This step can take a long time to run'''
fit_dist.plot_spectrum(nsample=20)
